# %% [markdown]
# ## 1. Install Libraries

# %%
# !pip install xgboost shap lime imbalanced-learn -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ## 2. Upload Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-67f3f582-2c96-48b2-9b58-03469a4c825d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67f3f582-2c96-48b2-9b58-03469a4c825d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 3. Verify Library Installation

# %%
# !pip install xgboost shap lime imbalanced-learn -q

print("✅ All libraries installed!")
# Out:
# ✅ All libraries installed!

# %% [markdown]
# ## 4. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, roc_auc_score, confusion_matrix,
                             roc_curve)
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import shap
import warnings
warnings.filterwarnings('ignore')

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %% [markdown]
# ## 5. Load Data and Initial Inspection

# %%
df = pd.read_csv('churn.csv')


print("Shape:", df.shape)
print("\nColumn Names:")
print(df.columns.tolist())
print("\nFirst 5 rows:")
df.head()
# Out:
# Shape: (10000, 14)
#
# Column Names:
# ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
#
# First 5 rows:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# ...

# %% [markdown]
# ## 6. Data Preprocessing (Part 1)

# %%
df = df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

df['Gender'] = LabelEncoder().fit_transform(df['Gender'])
df['Geography'] = LabelEncoder().fit_transform(df['Geography'])


print("Missing Values:")
print(df.isnull().sum())

print("\nClass Distribution:")
print(df['Exited'].value_counts())
print("\nChurn Rate:", round(df['Exited'].mean() * 100, 2), "%")

print("\n✅ Preprocessing done!")
df.head()
# Out:
# Missing Values:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
#
# Class Distribution:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
#
# Churn Rate: 20.37 %
#
# ✅ Preprocessing done!
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# ...

# %% [markdown]
# ## 7. Data Preprocessing (Part 2)

# %%
print("Current columns:", df.columns.tolist())

cols_to_drop = ['RowNumber', 'CustomerId', 'Surname']
cols_to_drop = [col for col in cols_to_drop if col in df.columns]
df = df.drop(cols_to_drop, axis=1)


df['Gender'] = LabelEncoder().fit_transform(df['Gender'])
df['Geography'] = LabelEncoder().fit_transform(df['Geography'])

print("Missing Values:")
print(df.isnull().sum())

print("\nClass Distribution:")
print(df['Exited'].value_counts())
print("\nChurn Rate:", round(df['Exited'].mean() * 100, 2), "%")

print("\n✅ Preprocessing done!")
df.head()
# Out:
# Current columns: ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
# Missing Values:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64
#
# Class Distribution:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
#
# Churn Rate: 20.37 %
#
# ✅ Preprocessing done!
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# ...

# %% [markdown]
# ## 8. Feature Engineering (Phase 5)

# %%
df['Balance_Salary_Ratio'] = df['Balance'] / (df['EstimatedSalary'] + 1)
df['Products_Per_Year'] = df['NumOfProducts'] / (df['Tenure'] + 1)
df['Age_Tenure_Ratio'] = df['Age'] / (df['Tenure'] + 1)

df['Is_High_Value'] = (df['Balance'] > df['Balance'].median()).astype(int)
df['Is_Senior'] = (df['Age'] > 45).astype(int)
df['Low_Activity'] = ((df['IsActiveMember'] == 0) & (df['NumOfProducts'] == 1)).astype(int)
df['High_Risk'] = ((df['IsActiveMember'] == 0) & (df['Balance'] > 0)).astype(int)

print("✅ New features created:")
print(df.columns.tolist())
print("\nDataset shape after feature engineering:", df.shape)
print("\n✅ Phase 5 Complete!")
# Out:
# ✅ New features created:
# ['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited', 'Balance_Salary_Ratio', 'Products_Per_Year', 'Age_Tenure_Ratio', 'Is_High_Value', 'Is_Senior', 'Low_Activity', 'High_Risk']
#
# Dataset shape after feature engineering: (10000, 18)
#
# ✅ Phase 5 Complete!

# %% [markdown]
# ## 9. Data Splitting and Resampling (Phase 6)

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)

print("Before SMOTE:")
print("Churned:", sum(y_train == 1), "| Not Churned:", sum(y_train == 0))

smote = SMOTE(random_state=42)
X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

print("\nAfter SMOTE:")
print("Churned:", sum(y_train_sm == 1), "| Not Churned:", sum(y_train_sm == 0))
print("\n✅ Phase 6 Complete!")
# Out:
# Before SMOTE:
# Churned: 1630 | Not Churned: 6370
#
# After SMOTE:
# Churned: 6370 | Not Churned: 6370
#
# ✅ Phase 6 Complete!

# %% [markdown]
# ## 10. Model Training (Phase 7)

# %%
# PHASE 7 - TRAIN ALL 4 MODELS

# Model 1: Logistic Regression
lr = LogisticRegression(random_state=42, max_iter=1000)
lr.fit(X_train_sm, y_train_sm)
print("✅ Logistic Regression trained!")

# Model 2: Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train_sm, y_train_sm)
print("✅ Random Forest trained!")

# Model 3: XGBoost
xgb = XGBClassifier(n_estimators=100, random_state=42,
                    eval_metric='logloss')
xgb.fit(X_train_sm, y_train_sm)
print("✅ XGBoost trained!")

# Model 4: Neural Network
nn = MLPClassifier(hidden_layer_sizes=(64, 32),
                   max_iter=300, random_state=42)
nn.fit(X_train_sm, y_train_sm)
print("✅ Neural Network trained!")

print("\n✅ Phase 7 Complete! All 4 models trained!")
# Out:
# ✅ Logistic Regression trained!
# ✅ Random Forest trained!
# ✅ XGBoost trained!
# ✅ Neural Network trained!
#
# ✅ Phase 7 Complete! All 4 models trained!

# %% [markdown]
# ## 11. Model Evaluation & Cross Validation (Phase 8)

# %%
# ================================================
# PHASE 8: MODEL EVALUATION + CROSS VALIDATION
# ================================================
from sklearn.model_selection import cross_val_score

models = {
    'Logistic Regression': lr,
    'Random Forest': rf,
    'XGBoost': xgb,
    'Neural Network': nn
}

results = {}

for name, model in models.items():
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]
    cv_scores = cross_val_score(model, X_scaled, y, cv=5, scoring='f1')

    results[name] = {
        'Accuracy': round(accuracy_score(y_test, y_pred), 4),
        'Precision': round(precision_score(y_test, y_pred), 4),
        'Recall': round(recall_score(y_test, y_pred), 4),
        'F1 Score': round(f1_score(y_test, y_pred), 4),
        'AUC': round(roc_auc_score(y_test, y_prob), 4),
        'CV F1 Mean': round(cv_scores.mean(), 4)
    }

results_df = pd.DataFrame(results).T
print(results_df)
# Out:
#                      Accuracy  Precision  Recall  F1 Score     AUC  CV F1 Mean
# Logistic Regression    0.7135     0.3869  0.6978    0.4978  0.7837      0.4237
# Random Forest          0.8410     0.6219  0.5577    0.5881  0.8418      0.5551
# XGBoost                0.8505     0.6656  0.5332    0.5921  0.8300      0.5853
# Neural Network         0.7990     0.5053  0.5897    0.5442  0.7868      0.5592

# %% [markdown]
# ## 12. Hybrid Ensemble Model

# %%
# ================================================
# HYBRID ENSEMBLE MODEL (Weighted Averaging)
# ================================================
import numpy as np

# Get probabilities from all models
lr_prob = lr.predict_proba(X_test)[:, 1]
rf_prob = rf.predict_proba(X_test)[:, 1]
xgb_prob = xgb.predict_proba(X_test)[:, 1]
nn_prob = nn.predict_proba(X_test)[:, 1]

# Weights based on F1 scores
f1_scores = [results['Logistic Regression']['F1 Score'],
             results['Random Forest']['F1 Score'],
             results['XGBoost']['F1 Score'],
             results['Neural Network']['F1 Score']]

weights = np.array(f1_scores) / sum(f1_scores)

# Weighted average ensemble
ensemble_prob = (weights[0] * lr_prob +
                 weights[1] * rf_prob +
                 weights[2] * xgb_prob +
                 weights[3] * nn_prob)

ensemble_pred = (ensemble_prob >= 0.5).astype(int)

results['Hybrid Ensemble'] = {
    'Accuracy': round(accuracy_score(y_test, ensemble_pred), 4),
    'Precision': round(precision_score(y_test, ensemble_pred), 4),
    'Recall': round(recall_score(y_test, ensemble_pred), 4),
    'F1 Score': round(f1_score(y_test, ensemble_pred), 4),
    'AUC': round(roc_auc_score(y_test, ensemble_prob), 4),
    'CV F1 Mean': 0.0
}

results_df = pd.DataFrame(results).T
print("✅ Hybrid Ensemble Model Complete!")
print(results_df)
# Out:
# ✅ Hybrid Ensemble Model Complete!
#                      Accuracy  Precision  Recall  F1 Score     AUC  CV F1 Mean
# Logistic Regression    0.7135     0.3869  0.6978    0.4978  0.7837      0.4237
# Random Forest          0.8410     0.6219  0.5577    0.5881  0.8418      0.5551
# XGBoost                0.8505     0.6656  0.5332    0.5921  0.8300      0.5853
# Neural Network         0.7990     0.5053  0.5897    0.5442  0.7868      0.5592
# Hybrid Ensemble        0.8425     0.6211  0.5799    0.5997  0.8471      0.0000

# %% [markdown]
# ## 13. Graph 1: Model Performance Comparison

# %%
# ================================================
# GRAPH 1: MODEL PERFORMANCE COMPARISON
# ================================================

colors = ['#2ecc71', '#3498db', '#e74c3c', '#f39c12', '#9b59b6']
metrics_to_plot = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC']
plot_df = results_df[metrics_to_plot]

fig, ax = plt.subplots(figsize=(14, 7))
x = np.arange(len(plot_df.index))
width = 0.15

for i, metric in enumerate(metrics_to_plot):
    bars = ax.bar(x + i * width, plot_df[metric],
                  width, label=metric, color=colors[i],
                  edgecolor='black', linewidth=0.5)
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                   xy=(bar.get_x() + bar.get_width() / 2, height),
                   xytext=(0, 3), textcoords="offset points",
                   ha='center', va='bottom', fontsize=7)

ax.set_title('Model Performance Comparison',
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.set_xticks(x + width * 2)
ax.set_xticklabels(plot_df.index, rotation=15, ha='right')
ax.legend(loc='lower right', fontsize=10)
ax.set_ylim(0, 1.1)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('graph1_model_comparison.png', dpi=300)
plt.show()

# %% [markdown]
# ## 14. Graph 2: Confusion Matrices

# %%
# ================================================
# GRAPH 2: CONFUSION MATRICES
# ================================================

all_models = {
    'Logistic Regression': lr,
    'Random Forest': rf,
    'XGBoost': xgb,
    'Neural Network': nn
}

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()
cmaps = ['Blues', 'Greens', 'Oranges', 'Purples']

for idx, (name, model) in enumerate(all_models.items()):
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmaps[idx],
                ax=axes[idx], linewidths=1,
                xticklabels=['Not Churned', 'Churned'],
                yticklabels=['Not Churned', 'Churned'])
    axes[idx].set_title(f'{name}', fontsize=13, fontweight='bold')
    axes[idx].set_xlabel('Predicted Label', fontsize=11)
    axes[idx].set_ylabel('True Label', fontsize=11)

plt.suptitle('Confusion Matrices - All Models',
             fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('graph2_confusion_matrices.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 15. Graph 3: ROC Curves

# %%
# ================================================
# GRAPH 3: ROC CURVES (FIXED)
# ================================================

plt.figure(figsize=(10, 7))
colors = ['#2ecc71', '#3498db', '#e74c3c', '#f39c12', '#9b59b6']
line_styles = ['-', '--', '-.', ':', '-']

# Get probabilities again
lr_prob = lr.predict_proba(X_test)[:, 1]
rf_prob = rf.predict_proba(X_test)[:, 1]
xgb_prob = xgb.predict_proba(X_test)[:, 1]
nn_prob = nn.predict_proba(X_test)[:, 1]
ensemble_prob = (weights[0] * lr_prob +
                 weights[1] * rf_prob +
                 weights[2] * xgb_prob +
                 weights[3] * nn_prob)

model_probs = {
    'Logistic Regression': lr_prob,
    'Random Forest': rf_prob,
    'XGBoost': xgb_prob,
    'Neural Network': nn_prob,
    'Hybrid Ensemble': ensemble_prob
}

for idx, (name, prob) in enumerate(model_probs.items()):
    fpr, tpr, _ = roc_curve(y_test, prob)
    auc = roc_auc_score(y_test, prob)
    plt.plot(fpr, tpr, label=f'{name} (AUC = {auc:.4f})',
             color=colors[idx], linewidth=2,
             linestyle=line_styles[idx])

plt.plot([0, 1], [0, 1], 'k--', linewidth=1.5, label='Random Classifier')
plt.fill_between([0, 1], [0, 1], alpha=0.1, color='gray')
plt.title('ROC Curves - All Models', fontsize=16, fontweight='bold')
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.legend(loc='lower right', fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('graph3_roc_curves.png', dpi=300)
plt.show()
print("✅ Graph 3 saved!")
# Out:
# ✅ Graph 3 saved!

# %% [markdown]
# ## 16. Graph 4: Precision, Recall & F1 Comparison

# %%
# ================================================
# GRAPH 4: PRECISION, RECALL & F1 COMPARISON
# ================================================

metrics = ['Precision', 'Recall', 'F1 Score']
model_names = list(results.keys())
x = np.arange(len(model_names))
width = 0.25
colors = ['#3498db', '#e74c3c', '#2ecc71']

fig, ax = plt.subplots(figsize=(14, 7))

for i, metric in enumerate(metrics):
    values = [results[m][metric] for m in model_names]
    bars = ax.bar(x + i * width, values, width,
                  label=metric, color=colors[i],
                  edgecolor='black', linewidth=0.5)
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                   xy=(bar.get_x() + bar.get_width() / 2, height),
                   xytext=(0, 3), textcoords="offset points",
                   ha='center', va='bottom', fontsize=8)

ax.set_title('Precision, Recall & F1 Score Comparison',
             fontsize=16, fontweight='bold')
ax.set_xlabel('Models', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.set_xticks(x + width)
ax.set_xticklabels(model_names, rotation=15, ha='right')
ax.legend(fontsize=11)
ax.set_ylim(0, 1.1)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig('graph4_precision_recall_f1.png', dpi=300)
plt.show()

# %% [markdown]
# ## 17. Graph 5: SHAP Feature Importance

# %%
# ================================================
# GRAPH 5: SHAP FEATURE IMPORTANCE
# ================================================

feature_names = df.drop('Exited', axis=1).columns.tolist()
explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test,
                  feature_names=feature_names,
                  show=False, plot_size=(12, 8))
plt.title('SHAP Feature Importance - XGBoost',
          fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('graph5_shap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 18. Graph 6: Churn Distribution by Geography & Gender

# %%
# ================================================
# GRAPH 6: CHURN DISTRIBUTION BY GEOGRAPHY & GENDER
# ================================================

# Reload original df for visualization
df_viz = pd.read_csv('churn (1).csv')
df_viz = df_viz.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

fig, axes = plt.subplots(1, 3, figsize=(16, 6))

# Plot 1: Churn Distribution Pie Chart
churn_counts = df_viz['Exited'].value_counts()
axes[0].pie(churn_counts, labels=['Not Churned', 'Churned'],
            autopct='%1.1f%%', colors=['#3498db', '#e74c3c'],
            startangle=90, explode=(0, 0.05))
axes[0].set_title('Overall Churn Distribution',
                   fontsize=13, fontweight='bold')

# Plot 2: Churn by Geography
geo_churn = df_viz.groupby('Geography')['Exited'].mean() * 100
bars = axes[1].bar(geo_churn.index, geo_churn.values,
                   color=['#2ecc71', '#e74c3c', '#3498db'],
                   edgecolor='black')
for bar in bars:
    height = bar.get_height()
    axes[1].annotate(f'{height:.1f}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points",
                    ha='center', fontsize=11)
axes[1].set_title('Churn Rate by Geography',
                   fontsize=13, fontweight='bold')
axes[1].set_xlabel('Geography')
axes[1].set_ylabel('Churn Rate (%)')
axes[1].grid(axis='y', alpha=0.3)

# Plot 3: Churn by Gender
gender_churn = df_viz.groupby('Gender')['Exited'].mean() * 100
bars = axes[2].bar(gender_churn.index, gender_churn.values,
                   color=['#f39c12', '#9b59b6'],
                   edgecolor='black')
for bar in bars:
    height = bar.get_height()
    axes[2].annotate(f'{height:.1f}%',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points",
                    ha='center', fontsize=11)
axes[2].set_title('Churn Rate by Gender',
                   fontsize=13, fontweight='bold')
axes[2].set_xlabel('Gender')
axes[2].set_ylabel('Churn Rate (%)')
axes[2].grid(axis='y', alpha=0.3)

plt.suptitle('Churn Distribution Analysis',
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('graph6_churn_distribution.png', dpi=300)
plt.show()

# %% [markdown]
# ## 19. Graph 7: Feature Correlation Heatmap

# %%
# ================================================
# GRAPH 7: FEATURE CORRELATION HEATMAP
# ================================================

plt.figure(figsize=(14, 10))
correlation = df.corr()
mask = np.triu(np.ones_like(correlation, dtype=bool))
sns.heatmap(correlation, mask=mask, annot=True,
            fmt='.2f', cmap='RdYlGn',
            linewidths=0.5, annot_kws={'size': 9},
            vmin=-1, vmax=1, center=0)
plt.title('Feature Correlation Heatmap',
          fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('graph7_correlation_heatmap.png', dpi=300)
plt.show()

# %% [markdown]
# ## 20. Download All Graphs

# %%
# ================================================
# DOWNLOAD ALL GRAPHS
# ================================================

from google.colab import files

graphs = ['graph1_model_comparison.png',
          'graph2_confusion_matrices.png',
          'graph3_roc_curves.png',
          'graph4_precision_recall_f1.png',
          'graph5_shap.png',
          'graph6_churn_distribution.png',
          'graph7_correlation_heatmap.png']

for graph in graphs:
    files.download(graph)
